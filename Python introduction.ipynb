# %% [markdown]
# # How to run a cell

# %% [markdown]
# ## How to run a cell

# %%
20+20
# Out:
# 40

# %% [markdown]
# ### How to run a cell

# %% [markdown]
# #### How to run a cell

# %% [markdown]
# # How to run a cell

# %% [raw]
# 1. control + Enter >> Used to run the current cell
# 2. Shift + Enter   >> Used to execute current cell and enter in the next cell
# 3. Alt + Enter     >> Used to execute current cell and create/add new blank cell

# %% [markdown]
# # Python introduction

# %%
Python is a popular programming language.
Python is independent lang .
Python is interpreter lang .
Python is high level lang . 
Python can be used on a server to create web applications.
Python is used for Data analysis and summerize the data.

# %%
# Features:

1. Multiple libraries
2. Easy to use
3. Portable ie. Python works on different platforms (Windows, Mac, Linux, Raspberry Pi, etc).
4. Data structures are user friendly
5. More functionality with less coding

# %% [markdown]
# # Print Function

# %% [raw]
# 1. print text on screen
# 2. print values of variables | values of expressions
# 3. print combination(text + values + expressions)

# %%
a  =  10
b  =  20 

print('Addition of a and b is -',a+b)
print('Addition of',a,'and',b,'is -',a+b)
print(f'Addition of {a} and {b} is -',a+b)
# Out:
# Addition of a and b is - 30
# Addition of 10 and 20 is - 30
# Addition of 10 and 20 is - 30

# %%
# print text
print('python programming language')
# Out:
# python programming language

# %%
print("python programming language")
# Out:
# python programming language

# %%
print('Machine learning')
# Out:
# Machine learning

# %%
a = 10 
print(a)
# Out:
# 10

# %%
# print variables and expressions
a = 25
b = 3
print(a)
print(b)
print(a,b)
print(a+b)
print(a*b)
# Out:
# 25
# 3
# 25 3
# 28
# 75

# %%
print(a)
print(b)
# Out:
# 30
# 100

# %%
# print combination of text and variables
print(a)
# Out:
# 25

# %%
a = 10 
b = 20
print('Addition of' ,a,' and', b, ' is -',a+b)
# Out:
# Addition of 10  and 20  is - 30

# %%
a = 30
b = 100
print('Addition of',a,'and',b,'is',a+b)
# Out:
# Addition of 30 and 100 is 130

# %% [markdown]
# # Comments

# %%
Comments are used to write description of a code line

Comments can be used when you dont want execution of a code line

# %%
print(9+8)   #this is addition 
print('Hello World')
# Out:
# 17
# Hello World

# %% [raw]
# 1. # >> To comment a single line
# 2. Control + /  >> TO comment multiple line
# 3. triple quotes

# %%
# We are learning comments
print("Hello")
print("1. We are learning Python and Data Science")
print("2. We are learning Python and Data Science")
print("3. We are learning Python and Data Science")
print("4. We are learning Python and Data Science")
print("5. We are learning Python and Data Science")
print("6. We are learning Python and Data Science")
# Out:
# Hello
# 1. We are learning Python and Data Science
# 2. We are learning Python and Data Science
# 3. We are learning Python and Data Science
# 4. We are learning Python and Data Science
# 5. We are learning Python and Data Science
# 6. We are learning Python and Data Science

# %%
# We are learning comments
print("Hello")
print("1. We are learning Python and Data Science")
print("2. We are learning Python and Data Science")
#print("3. We are learning Python and Data Science")
#print("4. We are learning Python and Data Science")
print("5. We are learning Python and Data Science")
print("6. We are learning Python and Data Science")
# Out:
# Hello
# 1. We are learning Python and Data Science
# 2. We are learning Python and Data Science
# 5. We are learning Python and Data Science
# 6. We are learning Python and Data Science

# %%
# We are learning comments
print("Hello")
print("1. We are learning Python and Data Science")
print("2. We are learning Python and Data Science")
print("3. We are learning Python and Data Science")
print("4. We are learning Python and Data Science")
print("5. We are learning Python and Data Science")
print("6. We are learning Python and Data Science")
# Out:
# Hello
# 1. We are learning Python and Data Science
# 2. We are learning Python and Data Science
# 3. We are learning Python and Data Science
# 4. We are learning Python and Data Science
# 5. We are learning Python and Data Science
# 6. We are learning Python and Data Science

# %%
 """Data science is an interdisciplinary field that uses scientific methods, processes, 
 algorithms and systems to extract knowledge and insights from noisy, structured and 
 unstructured data, and apply knowledge and actionable insights from data across a broad 
 range of application domains """
# Out:
# Hello

# %% [markdown]
# # Indentation

# %%
a =  10 
b =  20 

if a > b:
    print('A is greater than b')  
    print('-----------------')
else:
         
        print('b is greater than a')
        print('b is greater than a')
# Out:
# b is greater than a
# b is greater than a

# %%
Indentation refers to the spaces at the beginning of a code line.

Python uses indentation to indicate a block of code.

colon is used for creating a code block

python treats the code lines with same indentation level as single block of code

# %%
# write correct syntax with proper indentation
a = 12
if a>10:
 print('a is greater than 10')
 print('a is greater than 10')
# Out:
# a is greater than 10
# a is greater than 10

# %%
# Python will give you an error if you skip the indentation
a = 12
if a>10:
print('a is greater than 10')
# Out:
#   File "C:\Users\SUSHIL~1\AppData\Local\Temp/ipykernel_35660/576644124.py", line 4
#     print('a is greater than 10')
#     ^
# IndentationError: expected an indented block

# %%
# we can give any number of spaces
a = 12
if a>10:
    print('a is greater than 10')
# Out:
# a is greater than 10

# %%
# You have to use the same number of spaces in the same block of code, otherwise Python will give you an error
a = 12
if a>10:
    print('a is greater than 10')
    print('Indentation')
# Out:
# a is greater than 10
# Indentation

# %%
# You have to use the same number of spaces in the same block of code, otherwise Python will give you an error
a = 12
if a>10:
    print('a is greater than 10')
           print('Indentation')
# Out:
#   File "C:\Users\SUSHIL~1\AppData\Local\Temp/ipykernel_35660/3438930470.py", line 5
#     print('Indentation')
#     ^
# IndentationError: unexpected indent

# %%
a =  30
b  = 20 
if a<b:
    print('a is less than 10')
    print(' ----------------')
else:
        print(' ----------------')
        print(' ----------------')
# Out:
#  ----------------
#  ----------------
