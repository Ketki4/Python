# %%
import pandas as pd

import numpy as np

# %%
df = pd.read_excel(r"C:\Users\ketki\OneDrive\Desktop\excel\pandas - 1.xlsx")

# %%
df
# Out:
#       Row ID+O6G3A1:R6        Order ID Order Date     Month  Ship Date  \
# 0                 4918  CA-2019-160304 2019-01-01   January 2019-01-07
# 1                 4919  CA-2019-160304 2019-01-02   January 2019-01-07
# 2                 4920  CA-2019-160304 2019-01-02   January 2019-01-07
# 3                 3074  CA-2019-125206 2019-01-03   January 2019-01-05
# 4                 8604  US-2019-116365 2019-01-03   January 2019-01-08
# ...                ...             ...        ...       ...        ...
# 5896               907  CA-2020-143259 2020-12-30  December 2021-01-03
# 5897              1297  CA-2020-115427 2020-12-30  December 2021-01-03
# 5898              5092  CA-2020-156720 2020-12-30  December 2021-01-03
# 5899               909  CA-2020-143259 2020-12-30  December 2021-01-03
# 5900              5093  CA-2020-151450 2020-12-31  December 2021-01-04
#
#            Ship Mode Customer ID      Customer Name    Segment        Country  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row ID+O6G3A1:R6  5901 non-null   int64
#  1   Order ID          5901 non-null   object
#  2   Order Date        5901 non-null   datetime64[ns]
#  3   Month             5901 non-null   object
#  4   Ship Date         5901 non-null   datetime64[ns]
#  5   Ship Mode         5901 non-null   object
#  6   Customer ID       5901 non-null   object
#  7   Customer Name     5901 non-null   object
#  8   Segment           5901 non-null   object
#  9   Country           5901 non-null   object
#  10  City              5901 non-null   object
#  11  State             5901 non-null   object
#  12  Region            5901 non-null   object
#  13  Product ID        5901 non-null   object
#  14  Category          5901 non-null   object
#  15  Sub-Category      5901 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID+O6G3A1:R6       0
# Order ID               0
# Order Date             0
# Month                  0
# Ship Date              0
# Ship Mode              0
# Customer ID            0
# Customer Name          0
# Segment                0
# Country                0
# City                   0
# State                  0
# Region                 0
# Product ID             0
# Category               0
# Sub-Category           0
# Product Name           0
# Sales                  0
# Quantity               0
# Profit                 0
# Returns             5614
# Payment Mode           0
# ind1                5901
# ind2                5901
# dtype: int64

# %%
df.drop(["ind1","ind2"],axis=1,inplace=True)

# %%
df
# Out:
#       Row ID+O6G3A1:R6        Order ID Order Date     Month  Ship Date  \
# 0                 4918  CA-2019-160304 2019-01-01   January 2019-01-07
# 1                 4919  CA-2019-160304 2019-01-02   January 2019-01-07
# 2                 4920  CA-2019-160304 2019-01-02   January 2019-01-07
# 3                 3074  CA-2019-125206 2019-01-03   January 2019-01-05
# 4                 8604  US-2019-116365 2019-01-03   January 2019-01-08
# ...                ...             ...        ...       ...        ...
# 5896               907  CA-2020-143259 2020-12-30  December 2021-01-03
# 5897              1297  CA-2020-115427 2020-12-30  December 2021-01-03
# 5898              5092  CA-2020-156720 2020-12-30  December 2021-01-03
# 5899               909  CA-2020-143259 2020-12-30  December 2021-01-03
# 5900              5093  CA-2020-151450 2020-12-31  December 2021-01-04
#
#            Ship Mode Customer ID      Customer Name    Segment        Country  \
# ...

# %%
df.isnull().sum()
# Out:
# Row ID+O6G3A1:R6       0
# Order ID               0
# Order Date             0
# Month                  0
# Ship Date              0
# Ship Mode              0
# Customer ID            0
# Customer Name          0
# Segment                0
# Country                0
# City                   0
# State                  0
# Region                 0
# Product ID             0
# Category               0
# Sub-Category           0
# Product Name           0
# Sales                  0
# Quantity               0
# Profit                 0
# Returns             5614
# Payment Mode           0
# dtype: int64

# %% [markdown]
# FILTER DATA

# %%
data = pd.read_excel(r"C:\Users\ketki\OneDrive\Desktop\excel\data_3.xlsx")

# %%
data
# Out:
#     ID     Name Department  Age  Salary       City  Experience_Years
# 0    1    Alice         HR   25   45000   New York                 2
# 1    2      Bob         IT   30   60000  San Diego                 5
# 2    3  Charlie    Finance   28   55000    Chicago                 3
# 3    4    David         IT   35   75000   New York                 7
# 4    5     Emma         HR   29   48000     Boston                 3
# 5    6    Frank  Marketing   33   52000     Denver                 4
# 6    7    Grace    Finance   27   53000      Miami                 2
# 7    8    Henry         IT   31   68000    Seattle                 6
# 8    9    Irene  Marketing   26   47000    Chicago                 1
# 9   10     Jack    Finance   40   82000     Boston                10
# 10  11    Kelly         HR   24   42000   New York                 1
# 11  12     Liam         IT   37   79000    Seattle                 8
# 12  13      Mia    Finance   29   56000      Miami                 3
# ...

# %%
d_1 = data[data["Department"]=="IT"]

# %%
d_1
# Out:
#     ID   Name Department  Age  Salary       City  Experience_Years
# 1    2    Bob         IT   30   60000  San Diego                 5
# 3    4  David         IT   35   75000   New York                 7
# 7    8  Henry         IT   31   68000    Seattle                 6
# 11  12   Liam         IT   37   79000    Seattle                 8
# 15  16  Peter         IT   41   90000     Boston                12
# 18  19  Sarah         IT   30   64000      Miami                 5

# %%
d_2 = data[data["Department"]=="Finance"]

# %%
d_2
# Out:
#     ID     Name Department  Age  Salary      City  Experience_Years
# 2    3  Charlie    Finance   28   55000   Chicago                 3
# 6    7    Grace    Finance   27   53000     Miami                 2
# 9   10     Jack    Finance   40   82000    Boston                10
# 12  13      Mia    Finance   29   56000     Miami                 3
# 17  18   Robert    Finance   34   73000  New York                 7

# %%
d_3 = data[data["Age"]<25]

# %%
d_3
# Out:
#     ID   Name Department  Age  Salary      City  Experience_Years
# 10  11  Kelly         HR   24   42000  New York                 1

# %%
d_4 = data[(data["Salary"]>50000) & (data["Salary"]<60000)]

# %%
d_4
# Out:
#     ID     Name Department  Age  Salary     City  Experience_Years
# 2    3  Charlie    Finance   28   55000  Chicago                 3
# 5    6    Frank  Marketing   33   52000   Denver                 4
# 6    7    Grace    Finance   27   53000    Miami                 2
# 12  13      Mia    Finance   29   56000    Miami                 3
# 13  14     Noah         HR   32   51000   Denver                 6

# %%
d_5 = data.groupby("Department")["Salary"].mean()

# %%
d_5 =
# Out:
# Department
# Finance      63800.000000
# HR           46400.000000
# IT           72666.666667
# Marketing    54000.000000
# Name: Salary, dtype: float64
