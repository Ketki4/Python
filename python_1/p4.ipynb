# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\ketki\OneDrive\Desktop\excel\data_1.xlsx")

# %%
df
# Out:
#           Name  Age                 Email            Join_Date     Salary  \
# 0     John Doe   29      john@example.com  2021-06-15 00:00:00      50000
# 1   Jane Smith  NaN   jane.smith@mail.com  2020-12-06 00:00:00      52000
# 2          Bob   35           bobmail.com  2022-08-15 00:00:00    $48,000
# 3    Alice Lee   27         alice@lee.com  2020-11-01 00:00:00      46000
# 4          NaN   41       eric@domain.com  2022-05-19 00:00:00      51000
# 5       Mark X   38     markx@example.com                  NaN      54000
# 6     Tim Cook    -         tim@apple.com  2021-01-01 00:00:00        NaN
# 7   Lara Croft   33                   NaN  2019-03-25 00:00:00      49000
# 8    Jack Ryan   29         jack@ryan.com  2020-03-03 00:00:00      52000
# 9         Nina   25                 nina@  2021-08-08 00:00:00      47000
# 10    John Doe   29      john@example.com  2021-06-15 00:00:00      50000
# 11        Mike  abc         mike@mail.com           07/14/2022      50000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        18 non-null     object
#  1   Age         17 non-null     object
#  2   Email       18 non-null     object
#  3   Join_Date   18 non-null     object
#  4   Salary      18 non-null     object
#  5   Department  18 non-null     object
# dtypes: object(6)
# memory usage: 1.1+ KB

# %%
df.isnull().sum()
# Out:
# Name          2
# Age           3
# Email         2
# Join_Date     2
# Salary        2
# Department    2
# dtype: int64

# %%
df["Name"] = df["Name"].str.title()

# %%
df
# Out:
#           Name  Age                 Email            Join_Date     Salary  \
# 0     John Doe   29      john@example.com  2021-06-15 00:00:00      50000
# 1   Jane Smith  NaN   jane.smith@mail.com  2020-12-06 00:00:00      52000
# 2          Bob   35           bobmail.com  2022-08-15 00:00:00    $48,000
# 3    Alice Lee   27         alice@lee.com  2020-11-01 00:00:00      46000
# 4          NaN   41       eric@domain.com  2022-05-19 00:00:00      51000
# 5       Mark X   38     markx@example.com                  NaN      54000
# 6     Tim Cook    -         tim@apple.com  2021-01-01 00:00:00        NaN
# 7   Lara Croft   33                   NaN  2019-03-25 00:00:00      49000
# 8    Jack Ryan   29         jack@ryan.com  2020-03-03 00:00:00      52000
# 9         Nina   25                 nina@  2021-08-08 00:00:00      47000
# 10    John Doe   29      john@example.com  2021-06-15 00:00:00      50000
# 11        Mike  abc         mike@mail.com           07/14/2022      50000
# ...

# %%
df["Age"] = pd.to_numeric(df["Age"],errors="coerce")

# %%
df
# Out:
#           Name   Age                 Email            Join_Date     Salary  \
# 0     John Doe  29.0      john@example.com  2021-06-15 00:00:00      50000
# 1   Jane Smith   NaN   jane.smith@mail.com  2020-12-06 00:00:00      52000
# 2          Bob  35.0           bobmail.com  2022-08-15 00:00:00    $48,000
# 3    Alice Lee  27.0         alice@lee.com  2020-11-01 00:00:00      46000
# 4          NaN  41.0       eric@domain.com  2022-05-19 00:00:00      51000
# 5       Mark X  38.0     markx@example.com                  NaN      54000
# 6     Tim Cook   NaN         tim@apple.com  2021-01-01 00:00:00        NaN
# 7   Lara Croft  33.0                   NaN  2019-03-25 00:00:00      49000
# 8    Jack Ryan  29.0         jack@ryan.com  2020-03-03 00:00:00      52000
# 9         Nina  25.0                 nina@  2021-08-08 00:00:00      47000
# 10    John Doe  29.0      john@example.com  2021-06-15 00:00:00      50000
# ...

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df
# Out:
#           Name   Age                 Email            Join_Date     Salary  \
# 0     John Doe  29.0      john@example.com  2021-06-15 00:00:00      50000
# 1   Jane Smith  32.6   jane.smith@mail.com  2020-12-06 00:00:00      52000
# 2          Bob  35.0           bobmail.com  2022-08-15 00:00:00    $48,000
# 3    Alice Lee  27.0         alice@lee.com  2020-11-01 00:00:00      46000
# 4          NaN  41.0       eric@domain.com  2022-05-19 00:00:00      51000
# 5       Mark X  38.0     markx@example.com                  NaN      54000
# 6     Tim Cook  32.6         tim@apple.com  2021-01-01 00:00:00        NaN
# 7   Lara Croft  33.0                   NaN  2019-03-25 00:00:00      49000
# 8    Jack Ryan  29.0         jack@ryan.com  2020-03-03 00:00:00      52000
# 9         Nina  25.0                 nina@  2021-08-08 00:00:00      47000
# 10    John Doe  29.0      john@example.com  2021-06-15 00:00:00      50000
# ...

# %%
df["Age"]=df["Age"].astype("int")

# %%
df
# Out:
#           Name  Age                 Email            Join_Date     Salary  \
# 0     John Doe   29      john@example.com  2021-06-15 00:00:00      50000
# 1   Jane Smith   32   jane.smith@mail.com  2020-12-06 00:00:00      52000
# 2          Bob   35           bobmail.com  2022-08-15 00:00:00    $48,000
# 3    Alice Lee   27         alice@lee.com  2020-11-01 00:00:00      46000
# 4          NaN   41       eric@domain.com  2022-05-19 00:00:00      51000
# 5       Mark X   38     markx@example.com                  NaN      54000
# 6     Tim Cook   32         tim@apple.com  2021-01-01 00:00:00        NaN
# 7   Lara Croft   33                   NaN  2019-03-25 00:00:00      49000
# 8    Jack Ryan   29         jack@ryan.com  2020-03-03 00:00:00      52000
# 9         Nina   25                 nina@  2021-08-08 00:00:00      47000
# 10    John Doe   29      john@example.com  2021-06-15 00:00:00      50000
# 11        Mike   32         mike@mail.com           07/14/2022      50000
# ...

# %%
df["Email"] = df["Email"].fillna("abc@gmail.com")

# %%
df
# Out:
#           Name  Age                 Email            Join_Date     Salary  \
# 0     John Doe   29      john@example.com  2021-06-15 00:00:00      50000
# 1   Jane Smith   32   jane.smith@mail.com  2020-12-06 00:00:00      52000
# 2          Bob   35           bobmail.com  2022-08-15 00:00:00    $48,000
# 3    Alice Lee   27         alice@lee.com  2020-11-01 00:00:00      46000
# 4          NaN   41       eric@domain.com  2022-05-19 00:00:00      51000
# 5       Mark X   38     markx@example.com                  NaN      54000
# 6     Tim Cook   32         tim@apple.com  2021-01-01 00:00:00        NaN
# 7   Lara Croft   33         abc@gmail.com  2019-03-25 00:00:00      49000
# 8    Jack Ryan   29         jack@ryan.com  2020-03-03 00:00:00      52000
# 9         Nina   25                 nina@  2021-08-08 00:00:00      47000
# 10    John Doe   29      john@example.com  2021-06-15 00:00:00      50000
# 11        Mike   32         mike@mail.com           07/14/2022      50000
# ...

# %%
df["Join_Date"] = pd.to_datetime(df["Join_Date"],errors="coerce")

# %%
df
# Out:
#           Name  Age                 Email  Join_Date     Salary    Department
# 0     John Doe   29      john@example.com 2021-06-15      50000         Sales
# 1   Jane Smith   32   jane.smith@mail.com 2020-12-06      52000            HR
# 2          Bob   35           bobmail.com 2022-08-15    $48,000     marketing
# 3    Alice Lee   27         alice@lee.com 2020-11-01      46000            HR
# 4          NaN   41       eric@domain.com 2022-05-19      51000       Finance
# 5       Mark X   38     markx@example.com        NaT      54000         SALES
# 6     Tim Cook   32         tim@apple.com 2021-01-01        NaN          Tech
# 7   Lara Croft   33         abc@gmail.com 2019-03-25      49000   archaeology
# 8    Jack Ryan   29         jack@ryan.com 2020-03-03      52000  Intelligence
# 9         Nina   25                 nina@ 2021-08-08      47000            HR
# 10    John Doe   29      john@example.com 2021-06-15      50000         Sales
# ...

# %%
df["Join_Date"].ffill(inplace=True)

# %%
df
# Out:
#           Name  Age                 Email  Join_Date     Salary    Department
# 0     John Doe   29      john@example.com 2021-06-15      50000         Sales
# 1   Jane Smith   32   jane.smith@mail.com 2020-12-06      52000            HR
# 2          Bob   35           bobmail.com 2022-08-15    $48,000     marketing
# 3    Alice Lee   27         alice@lee.com 2020-11-01      46000            HR
# 4          NaN   41       eric@domain.com 2022-05-19      51000       Finance
# 5       Mark X   38     markx@example.com 2022-05-19      54000         SALES
# 6     Tim Cook   32         tim@apple.com 2021-01-01        NaN          Tech
# 7   Lara Croft   33         abc@gmail.com 2019-03-25      49000   archaeology
# 8    Jack Ryan   29         jack@ryan.com 2020-03-03      52000  Intelligence
# 9         Nina   25                 nina@ 2021-08-08      47000            HR
# 10    John Doe   29      john@example.com 2021-06-15      50000         Sales
# ...

# %%
df["Salary"] = df["Salary"].astype("str").str.replace(r"[/,$,]","",regex=True)

# %%
df
# Out:
#           Name  Age                 Email  Join_Date     Salary    Department
# 0     John Doe   29      john@example.com 2021-06-15      50000         Sales
# 1   Jane Smith   32   jane.smith@mail.com 2020-12-06      52000            HR
# 2          Bob   35           bobmail.com 2022-08-15      48000     marketing
# 3    Alice Lee   27         alice@lee.com 2020-11-01      46000            HR
# 4          NaN   41       eric@domain.com 2022-05-19      51000       Finance
# 5       Mark X   38     markx@example.com 2022-05-19      54000         SALES
# 6     Tim Cook   32         tim@apple.com 2021-01-01        nan          Tech
# 7   Lara Croft   33         abc@gmail.com 2019-03-25      49000   archaeology
# 8    Jack Ryan   29         jack@ryan.com 2020-03-03      52000  Intelligence
# 9         Nina   25                 nina@ 2021-08-08      47000            HR
# 10    John Doe   29      john@example.com 2021-06-15      50000         Sales
# ...

# %%
df["Salary"] = pd.to_numeric(df["Salary"],errors="coerce")

# %%
df
# Out:
#           Name  Age                 Email  Join_Date   Salary    Department
# 0     John Doe   29      john@example.com 2021-06-15  50000.0         Sales
# 1   Jane Smith   32   jane.smith@mail.com 2020-12-06  52000.0            HR
# 2          Bob   35           bobmail.com 2022-08-15  48000.0     marketing
# 3    Alice Lee   27         alice@lee.com 2020-11-01  46000.0            HR
# 4          NaN   41       eric@domain.com 2022-05-19  51000.0       Finance
# 5       Mark X   38     markx@example.com 2022-05-19  54000.0         SALES
# 6     Tim Cook   32         tim@apple.com 2021-01-01      NaN          Tech
# 7   Lara Croft   33         abc@gmail.com 2019-03-25  49000.0   archaeology
# 8    Jack Ryan   29         jack@ryan.com 2020-03-03  52000.0  Intelligence
# 9         Nina   25                 nina@ 2021-08-08  47000.0            HR
# 10    John Doe   29      john@example.com 2021-06-15  50000.0         Sales
# ...

# %%
df["Salary"] = df["Salary"].fillna(df["Salary"].min())

# %%
df
# Out:
#           Name  Age                 Email  Join_Date   Salary    Department
# 0     John Doe   29      john@example.com 2021-06-15  50000.0         Sales
# 1   Jane Smith   32   jane.smith@mail.com 2020-12-06  52000.0            HR
# 2          Bob   35           bobmail.com 2022-08-15  48000.0     marketing
# 3    Alice Lee   27         alice@lee.com 2020-11-01  46000.0            HR
# 4          NaN   41       eric@domain.com 2022-05-19  51000.0       Finance
# 5       Mark X   38     markx@example.com 2022-05-19  54000.0         SALES
# 6     Tim Cook   32         tim@apple.com 2021-01-01  46000.0          Tech
# 7   Lara Croft   33         abc@gmail.com 2019-03-25  49000.0   archaeology
# 8    Jack Ryan   29         jack@ryan.com 2020-03-03  52000.0  Intelligence
# 9         Nina   25                 nina@ 2021-08-08  47000.0            HR
# 10    John Doe   29      john@example.com 2021-06-15  50000.0         Sales
# ...

# %%
df["Salary"] = df["Salary"].astype("int")

# %%
df
# Out:
#           Name  Age                 Email  Join_Date  Salary    Department
# 0     John Doe   29      john@example.com 2021-06-15   50000         Sales
# 1   Jane Smith   32   jane.smith@mail.com 2020-12-06   52000            HR
# 2          Bob   35           bobmail.com 2022-08-15   48000     marketing
# 3    Alice Lee   27         alice@lee.com 2020-11-01   46000            HR
# 4          NaN   41       eric@domain.com 2022-05-19   51000       Finance
# 5       Mark X   38     markx@example.com 2022-05-19   54000         SALES
# 6     Tim Cook   32         tim@apple.com 2021-01-01   46000          Tech
# 7   Lara Croft   33         abc@gmail.com 2019-03-25   49000   archaeology
# 8    Jack Ryan   29         jack@ryan.com 2020-03-03   52000  Intelligence
# 9         Nina   25                 nina@ 2021-08-08   47000            HR
# 10    John Doe   29      john@example.com 2021-06-15   50000         Sales
# ...

# %%
df["Department"] = df["Department"].fillna("IT")

# %%
df
# Out:
#           Name  Age                 Email  Join_Date  Salary    Department
# 0     John Doe   29      john@example.com 2021-06-15   50000         Sales
# 1   Jane Smith   32   jane.smith@mail.com 2020-12-06   52000            HR
# 2          Bob   35           bobmail.com 2022-08-15   48000     marketing
# 3    Alice Lee   27         alice@lee.com 2020-11-01   46000            HR
# 4          NaN   41       eric@domain.com 2022-05-19   51000       Finance
# 5       Mark X   38     markx@example.com 2022-05-19   54000         SALES
# 6     Tim Cook   32         tim@apple.com 2021-01-01   46000          Tech
# 7   Lara Croft   33         abc@gmail.com 2019-03-25   49000   archaeology
# 8    Jack Ryan   29         jack@ryan.com 2020-03-03   52000  Intelligence
# 9         Nina   25                 nina@ 2021-08-08   47000            HR
# 10    John Doe   29      john@example.com 2021-06-15   50000         Sales
# ...

# %%
df.loc[2,"Salary"]=50000

# %%
df
# Out:
#           Name  Age                 Email  Join_Date  Salary    Department  \
# 0     John Doe   29      john@example.com 2021-06-15   50000         Sales
# 1   Jane Smith   32   jane.smith@mail.com 2020-12-06   52000            HR
# 2          Bob   35           bobmail.com 2022-08-15   50000     marketing
# 3    Alice Lee   27         alice@lee.com 2020-11-01   46000            HR
# 4          NaN   41       eric@domain.com 2022-05-19   51000       Finance
# 5       Mark X   38     markx@example.com 2022-05-19   54000         SALES
# 6     Tim Cook   32         tim@apple.com 2021-01-01   46000          Tech
# 7   Lara Croft   33         abc@gmail.com 2019-03-25   49000   archaeology
# 8    Jack Ryan   29         jack@ryan.com 2020-03-03   52000  Intelligence
# 9         Nina   25                 nina@ 2021-08-08   47000            HR
# 10    John Doe   29      john@example.com 2021-06-15   50000         Sales
# ...

# %%
df.loc[19] = ("kitu", 21, "abc@gmail.com", "2025-02-09",45000, "HR",56000)

# %%
df
# Out:
#           Name  Age                 Email  Join_Date  Salary    Department  \
# 0     John Doe   29      john@example.com 2021-06-15   50000         Sales
# 1   Jane Smith   32   jane.smith@mail.com 2020-12-06   52000            HR
# 2          Bob   35           bobmail.com 2022-08-15   50000     marketing
# 3    Alice Lee   27         alice@lee.com 2020-11-01   46000            HR
# 4          NaN   41       eric@domain.com 2022-05-19   51000       Finance
# 5       Mark X   38     markx@example.com 2022-05-19   54000         SALES
# 6     Tim Cook   32         tim@apple.com 2021-01-01   46000          Tech
# 7   Lara Croft   33         abc@gmail.com 2019-03-25   49000   archaeology
# 8    Jack Ryan   29         jack@ryan.com 2020-03-03   52000  Intelligence
# 9         Nina   25                 nina@ 2021-08-08   47000            HR
# 10    John Doe   29      john@example.com 2021-06-15   50000         Sales
# ...

# %%
df.drop("Salary",axis=1)
# Out:
#           Name  Age                 Email  Join_Date    Department  \
# 0     John Doe   29      john@example.com 2021-06-15         Sales
# 1   Jane Smith   32   jane.smith@mail.com 2020-12-06            HR
# 2          Bob   35           bobmail.com 2022-08-15     marketing
# 3    Alice Lee   27         alice@lee.com 2020-11-01            HR
# 4          NaN   41       eric@domain.com 2022-05-19       Finance
# 5       Mark X   38     markx@example.com 2022-05-19         SALES
# 6     Tim Cook   32         tim@apple.com 2021-01-01          Tech
# 7   Lara Croft   33         abc@gmail.com 2019-03-25   archaeology
# 8    Jack Ryan   29         jack@ryan.com 2020-03-03  Intelligence
# 9         Nina   25                 nina@ 2021-08-08            HR
# 10    John Doe   29      john@example.com 2021-06-15         Sales
# 11        Mike   32         mike@mail.com 2022-07-14   Engineering
# 12         NaN   32         abc@gmail.com 2022-07-14            IT
# ...

# %%
df["Department"] = "HR"

# %%
df
# Out:
#           Name  Age                 Email  Join_Date  Salary Department  \
# 0     John Doe   29      john@example.com 2021-06-15   50000         HR
# 1   Jane Smith   32   jane.smith@mail.com 2020-12-06   52000         HR
# 2          Bob   35           bobmail.com 2022-08-15   50000         HR
# 3    Alice Lee   27         alice@lee.com 2020-11-01   46000         HR
# 4          NaN   41       eric@domain.com 2022-05-19   51000         HR
# 5       Mark X   38     markx@example.com 2022-05-19   54000         HR
# 6     Tim Cook   32         tim@apple.com 2021-01-01   46000         HR
# 7   Lara Croft   33         abc@gmail.com 2019-03-25   49000         HR
# 8    Jack Ryan   29         jack@ryan.com 2020-03-03   52000         HR
# 9         Nina   25                 nina@ 2021-08-08   47000         HR
# 10    John Doe   29      john@example.com 2021-06-15   50000         HR
# 11        Mike   32         mike@mail.com 2022-07-14   50000         HR
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot   as plt

# %%
d1 = [2,4,6,8,10,12]
d2 = [20,30,50,70,90,100]

# %%
plt.plot(d1,d2,marker="o",color="r",linestyle="--")

plt.xlabel("d1")

plt.ylabel("d2")

plt.title("line chart",fontsize=14)

plt.show()

# %%
Region  = ["North","South","East","West"]
Sales = [100,200,300,400]

# %%
plt.bar(Region,Sales,color="g",edgecolor="black",linewidth=2.5)
# Out:
# <BarContainer object of 4 artists>

# %%
Grade = ["A","B","C","D"]

Profit = ["200","400","600","900"]

# %%
plt.pie(Profit,labels=Grade,autopct="%.f%%",startangle=1116)

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
de = pd.read_excel(r"C:\Users\ketki\OneDrive\Desktop\excel\DV - 1 (1).xlsx")

# %%
de
# Out:
#     ID Region Product  Sales  Quantity       Date
# 0    1   East       A    200         2 2025-01-01
# 1    2   West       B    340         3 2025-01-02
# 2    3   East       C    120         1 2025-01-03
# 3    4  South       A    300         2 2025-01-04
# 4    5  North       B    500         4 2025-01-05
# 5    6   East       C    150         1 2025-01-06
# 6    7   West       A    220         2 2025-01-07
# 7    8  South       B    330         3 2025-01-08
# 8    9  North       C    280         2 2025-01-09
# 9   10   East       A    210         2 2025-01-10
# 10  11   West       B    430         4 2025-01-11
# 11  12  South       C    130         1 2025-01-12
# 12  13  North       A    500         5 2025-01-13
# 13  14   East       B    310         3 2025-01-14
# 14  15   West       C    170         1 2025-01-15
# 15  16  South       A    290         2 2025-01-16
# 16  17  North       B    410         3 2025-01-17
# 17  18   East       C    160         1 2025-01-18
# ...

# %%
sns.lineplot(x="Date",y="Sales",data=de,marker="o",color="r")

plt.xticks(rotation=45)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[99], line 3
#       1 sns.lineplot(x="Date",y="Sales",data=de,marker="o",color="r")
# ----> 3 plt.xticks(rotation=45)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'xticks'
