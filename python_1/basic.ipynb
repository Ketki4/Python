# %% [markdown]
# Basic python start

# %% [markdown]
# #print()
# #type()
# #len()

# %%
a = 56

# %%
a = 56
print(a)
# Out:
# 56

# %% [markdown]
# Check the name of datatype

# %%
a = 56
print(type(a))
# Out:
# <class 'int'>

# %%
abc = "hello world"
type(abc)
# Out:
# str

# %% [markdown]
# Positive and Negative Indexing

# %%
a = "this is python"
print(a[3])
# Out:
# s

# %%
a = "this is python"
print(a[-1])
# Out:
# n

# %%
a = "this is python"
print(a[5])
# Out:
# i

# %% [markdown]
# Slicing
#
# [Start : Stop : Step]

# %%
a = "this is python"
print(a[0:4:1])
# Out:
# this

# %%
D.lower(0,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 D.lower(0,1)
#
# TypeError: str.lower() takes no arguments (2 given)

# %%
D = " GANPATI"

print(D[0:3:].upper()+D[3].lower()+D[4:7:].upper())
# Out:
#  GAnPAT
