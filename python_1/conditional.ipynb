# %% [markdown]
# if
# elif
# else
# input()
# try()
# except()

# %%
A = 12
B = 13

# %%
if A > B :
    print("A is greater than B")

else:
    print("B is greater than A")
# Out:
# B is greater than A

# %%
c = 7
d = 7

# %%
if c > d:
    print("c is greater tha  d")
elif c==d:
    print("c is equal to d")

else:
    print("d is smaller than c")
# Out:
# c is equal to d

# %%
num = 20

# %%
print(num)
# Out:
# (20, -12)

# %%
if num:
    print("value is positive")

else:
    print("value is negative")
# Out:
# value is positive

# %%
num = -30

# %%
age = int(input(" enter your age:"))

# %%
if age < 0:
    print("check your age")
    
elif (age>18) and (age < 75):
    print("eligible")
else:
    print("not eligible")
# Out:
# check your age

# %% [markdown]
# EXCEPTION HANDLING:
#
# # zerodivisioneroor----> "when dividing a number by zero"
# # valueerror ----> "when type is correct but value(input) is wrong"
# # typeeroor ----> "when operation apllied on wrong datatype"
# # indexeroor ----> "when index is out of range means index doenot exixst in list"
# # nameerror ----> " when variable is not defined"
# # filenotfounderror---> "when trying to open file that does not exisit"
# # attributeeroor -----> "when apllied wrong method on wrong dataype"
