# %%
import pandas as pd

# %%
dr = pd.read_excel(r"C:\Users\ketki\OneDrive\Desktop\excel\data_set_2.xlsx")

# %%
dr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          20 non-null     int64
#  1   Name        18 non-null     object
#  2   Age         17 non-null     object
#  3   Email       19 non-null     object
#  4   Join Date   20 non-null     datetime64[ns]
#  5   Salary      19 non-null     object
#  6   Department  20 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 1.2+ KB

# %%
dr.isnull().sum()
# Out:
# ID            0
# Name          2
# Age           3
# Email         1
# Join Date     0
# Salary        1
# Department    0
# dtype: int64

# %%
dr
# Out:
#     ID         Name  Age                  Email  Join Date   Salary  \
# 0    1   john smith   29   john.smith@email.com 2020-01-15  $45,000
# 1    2   MARY JONES   34    mary.jones@emailcom 2021-03-15    52000
# 2    3   Mike Brown  NaN   mike.brown@email.com 2022-04-20      48K
# 3    4   anna WHITE   28   anna.white@email.com 2021-11-03  $50,000
# 4    5   John Smith   29   john.smith@email.com 2020-01-15  $45,000
# 5    6  elena gomez   31  elena.gomez@email.com 2023-07-03      NaN
# 6    7   mike Brown  NaN   mike.brown@email.com 2022-04-20    48000
# 7    8   mary jones   34   mary.jones@email.com 2021-03-15    52000
# 8    9          NaN   25      unknown@email.com 2020-08-10    42000
# 9   10    lucas roy   27    lucas.roy@email.com 2023-01-05      46K
# 10  11  elena gomez   31  elena.gomez@email.com 2023-07-03  $49,500
# 11  12     david li    -      davidli@email.com 2022-12-10    49000
# 12  13     David Li  NaN      davidli@email.com 2022-12-10    49000
# ...

# %%
dr["Age"] = pd.to_numeric(dr["Age"],errors="coerce")

# %%
dr
# Out:
#     ID         Name   Age                  Email  Join Date   Salary  \
# 0    1   john smith  29.0   john.smith@email.com 2020-01-15  $45,000
# 1    2   MARY JONES  34.0    mary.jones@emailcom 2021-03-15    52000
# 2    3   Mike Brown   NaN   mike.brown@email.com 2022-04-20      48K
# 3    4   anna WHITE  28.0   anna.white@email.com 2021-11-03  $50,000
# 4    5   John Smith  29.0   john.smith@email.com 2020-01-15  $45,000
# 5    6  elena gomez  31.0  elena.gomez@email.com 2023-07-03      NaN
# 6    7   mike Brown   NaN   mike.brown@email.com 2022-04-20    48000
# 7    8   mary jones  34.0   mary.jones@email.com 2021-03-15    52000
# 8    9          NaN  25.0      unknown@email.com 2020-08-10    42000
# 9   10    lucas roy  27.0    lucas.roy@email.com 2023-01-05      46K
# 10  11  elena gomez  31.0  elena.gomez@email.com 2023-07-03  $49,500
# 11  12     david li   NaN      davidli@email.com 2022-12-10    49000
# 12  13     David Li   NaN      davidli@email.com 2022-12-10    49000
# ...

# %%
dr["Age"] = dr["Age"].fillna(dr["Age"].mean())

# %%
dr
# Out:
#     ID         Name   Age                  Email  Join Date   Salary  \
# 0    1   john smith  29.0   john.smith@email.com 2020-01-15  $45,000
# 1    2   MARY JONES  34.0    mary.jones@emailcom 2021-03-15    52000
# 2    3   Mike Brown  30.0   mike.brown@email.com 2022-04-20      48K
# 3    4   anna WHITE  28.0   anna.white@email.com 2021-11-03  $50,000
# 4    5   John Smith  29.0   john.smith@email.com 2020-01-15  $45,000
# 5    6  elena gomez  31.0  elena.gomez@email.com 2023-07-03      NaN
# 6    7   mike Brown  30.0   mike.brown@email.com 2022-04-20    48000
# 7    8   mary jones  34.0   mary.jones@email.com 2021-03-15    52000
# 8    9          NaN  25.0      unknown@email.com 2020-08-10    42000
# 9   10    lucas roy  27.0    lucas.roy@email.com 2023-01-05      46K
# 10  11  elena gomez  31.0  elena.gomez@email.com 2023-07-03  $49,500
# 11  12     david li  30.0      davidli@email.com 2022-12-10    49000
# 12  13     David Li  30.0      davidli@email.com 2022-12-10    49000
# ...

# %%
dr["Age"] = dr["Age"].astype("int")

# %%
dr
# Out:
#     ID         Name  Age                  Email  Join Date   Salary  \
# 0    1   john smith   29   john.smith@email.com 2020-01-15  $45,000
# 1    2   MARY JONES   34    mary.jones@emailcom 2021-03-15    52000
# 2    3   Mike Brown   30   mike.brown@email.com 2022-04-20      48K
# 3    4   anna WHITE   28   anna.white@email.com 2021-11-03  $50,000
# 4    5   John Smith   29   john.smith@email.com 2020-01-15  $45,000
# 5    6  elena gomez   31  elena.gomez@email.com 2023-07-03      NaN
# 6    7   mike Brown   30   mike.brown@email.com 2022-04-20    48000
# 7    8   mary jones   34   mary.jones@email.com 2021-03-15    52000
# 8    9          NaN   25      unknown@email.com 2020-08-10    42000
# 9   10    lucas roy   27    lucas.roy@email.com 2023-01-05      46K
# 10  11  elena gomez   31  elena.gomez@email.com 2023-07-03  $49,500
# 11  12     david li   30      davidli@email.com 2022-12-10    49000
# 12  13     David Li   30      davidli@email.com 2022-12-10    49000
# ...

# %%
dr["Email"] = dr["Email"].fillna("xyz@gmail.com")

# %%
dr
# Out:
#     ID         Name  Age                  Email  Join Date   Salary  \
# 0    1   john smith   29   john.smith@email.com 2020-01-15  $45,000
# 1    2   MARY JONES   34    mary.jones@emailcom 2021-03-15    52000
# 2    3   Mike Brown   30   mike.brown@email.com 2022-04-20      48K
# 3    4   anna WHITE   28   anna.white@email.com 2021-11-03  $50,000
# 4    5   John Smith   29   john.smith@email.com 2020-01-15  $45,000
# 5    6  elena gomez   31  elena.gomez@email.com 2023-07-03      NaN
# 6    7   mike Brown   30   mike.brown@email.com 2022-04-20    48000
# 7    8   mary jones   34   mary.jones@email.com 2021-03-15    52000
# 8    9          NaN   25      unknown@email.com 2020-08-10    42000
# 9   10    lucas roy   27    lucas.roy@email.com 2023-01-05      46K
# 10  11  elena gomez   31  elena.gomez@email.com 2023-07-03  $49,500
# 11  12     david li   30      davidli@email.com 2022-12-10    49000
# 12  13     David Li   30      davidli@email.com 2022-12-10    49000
# ...

# %%
dr["Name"] = dr["Name"].str.title()

# %%
dr
# Out:
#     ID         Name  Age                  Email  Join Date   Salary  \
# 0    1   John Smith   29   john.smith@email.com 2020-01-15  $45,000
# 1    2   Mary Jones   34    mary.jones@emailcom 2021-03-15    52000
# 2    3   Mike Brown   30   mike.brown@email.com 2022-04-20      48K
# 3    4   Anna White   28   anna.white@email.com 2021-11-03  $50,000
# 4    5   John Smith   29   john.smith@email.com 2020-01-15  $45,000
# 5    6  Elena Gomez   31  elena.gomez@email.com 2023-07-03      NaN
# 6    7   Mike Brown   30   mike.brown@email.com 2022-04-20    48000
# 7    8   Mary Jones   34   mary.jones@email.com 2021-03-15    52000
# 8    9          NaN   25      unknown@email.com 2020-08-10    42000
# 9   10    Lucas Roy   27    lucas.roy@email.com 2023-01-05      46K
# 10  11  Elena Gomez   31  elena.gomez@email.com 2023-07-03  $49,500
# 11  12     David Li   30      davidli@email.com 2022-12-10    49000
# 12  13     David Li   30      davidli@email.com 2022-12-10    49000
# ...

# %%
dr["Department"] = dr["Department"].str.upper()

# %%
dr
# Out:
#     ID         Name  Age                  Email  Join Date   Salary  \
# 0    1   John Smith   29   john.smith@email.com 2020-01-15  $45,000
# 1    2   Mary Jones   34    mary.jones@emailcom 2021-03-15    52000
# 2    3   Mike Brown   30   mike.brown@email.com 2022-04-20      48K
# 3    4   Anna White   28   anna.white@email.com 2021-11-03  $50,000
# 4    5   John Smith   29   john.smith@email.com 2020-01-15  $45,000
# 5    6  Elena Gomez   31  elena.gomez@email.com 2023-07-03      NaN
# 6    7   Mike Brown   30   mike.brown@email.com 2022-04-20    48000
# 7    8   Mary Jones   34   mary.jones@email.com 2021-03-15    52000
# 8    9          NaN   25      unknown@email.com 2020-08-10    42000
# 9   10    Lucas Roy   27    lucas.roy@email.com 2023-01-05      46K
# 10  11  Elena Gomez   31  elena.gomez@email.com 2023-07-03  $49,500
# 11  12     David Li   30      davidli@email.com 2022-12-10    49000
# 12  13     David Li   30      davidli@email.com 2022-12-10    49000
# ...

# %%
dr["Salary"] = dr["Salary"].astype("str").str.replace(r"[/$,K]","",regex=True)

# %%
dr
# Out:
#     ID         Name  Age                  Email  Join Date Salary  \
# 0    1   John Smith   29   john.smith@email.com 2020-01-15  45000
# 1    2   Mary Jones   34    mary.jones@emailcom 2021-03-15  52000
# 2    3   Mike Brown   30   mike.brown@email.com 2022-04-20     48
# 3    4   Anna White   28   anna.white@email.com 2021-11-03  50000
# 4    5   John Smith   29   john.smith@email.com 2020-01-15  45000
# 5    6  Elena Gomez   31  elena.gomez@email.com 2023-07-03    nan
# 6    7   Mike Brown   30   mike.brown@email.com 2022-04-20  48000
# 7    8   Mary Jones   34   mary.jones@email.com 2021-03-15  52000
# 8    9          NaN   25      unknown@email.com 2020-08-10  42000
# 9   10    Lucas Roy   27    lucas.roy@email.com 2023-01-05     46
# 10  11  Elena Gomez   31  elena.gomez@email.com 2023-07-03  49500
# 11  12     David Li   30      davidli@email.com 2022-12-10  49000
# 12  13     David Li   30      davidli@email.com 2022-12-10  49000
# ...

# %%
dr["Salary"] = pd.to_numeric(dr["Salary"],errors="coerce")

# %%
dr
# Out:
#     ID         Name  Age                  Email  Join Date   Salary  \
# 0    1   John Smith   29   john.smith@email.com 2020-01-15  45000.0
# 1    2   Mary Jones   34    mary.jones@emailcom 2021-03-15  52000.0
# 2    3   Mike Brown   30   mike.brown@email.com 2022-04-20     48.0
# 3    4   Anna White   28   anna.white@email.com 2021-11-03  50000.0
# 4    5   John Smith   29   john.smith@email.com 2020-01-15  45000.0
# 5    6  Elena Gomez   31  elena.gomez@email.com 2023-07-03      NaN
# 6    7   Mike Brown   30   mike.brown@email.com 2022-04-20  48000.0
# 7    8   Mary Jones   34   mary.jones@email.com 2021-03-15  52000.0
# 8    9          NaN   25      unknown@email.com 2020-08-10  42000.0
# 9   10    Lucas Roy   27    lucas.roy@email.com 2023-01-05     46.0
# 10  11  Elena Gomez   31  elena.gomez@email.com 2023-07-03  49500.0
# 11  12     David Li   30      davidli@email.com 2022-12-10  49000.0
# 12  13     David Li   30      davidli@email.com 2022-12-10  49000.0
# ...

# %%
dr["Salary"] = dr["Salary"].fillna(dr["Salary"].min())

# %%
dr
# Out:
#     ID         Name  Age                  Email  Join Date   Salary  \
# 0    1   John Smith   29   john.smith@email.com 2020-01-15  45000.0
# 1    2   Mary Jones   34    mary.jones@emailcom 2021-03-15  52000.0
# 2    3   Mike Brown   30   mike.brown@email.com 2022-04-20     48.0
# 3    4   Anna White   28   anna.white@email.com 2021-11-03  50000.0
# 4    5   John Smith   29   john.smith@email.com 2020-01-15  45000.0
# 5    6  Elena Gomez   31  elena.gomez@email.com 2023-07-03     46.0
# 6    7   Mike Brown   30   mike.brown@email.com 2022-04-20  48000.0
# 7    8   Mary Jones   34   mary.jones@email.com 2021-03-15  52000.0
# 8    9          NaN   25      unknown@email.com 2020-08-10  42000.0
# 9   10    Lucas Roy   27    lucas.roy@email.com 2023-01-05     46.0
# 10  11  Elena Gomez   31  elena.gomez@email.com 2023-07-03  49500.0
# 11  12     David Li   30      davidli@email.com 2022-12-10  49000.0
# 12  13     David Li   30      davidli@email.com 2022-12-10  49000.0
# ...

# %%
dr["Salary"] = dr["Salary"].astype("int")

# %%
dr
# Out:
#     ID         Name  Age                  Email  Join Date  Salary  \
# 0    1   John Smith   29   john.smith@email.com 2020-01-15   45000
# 1    2   Mary Jones   34    mary.jones@emailcom 2021-03-15   52000
# 2    3   Mike Brown   30   mike.brown@email.com 2022-04-20      48
# 3    4   Anna White   28   anna.white@email.com 2021-11-03   50000
# 4    5   John Smith   29   john.smith@email.com 2020-01-15   45000
# 5    6  Elena Gomez   31  elena.gomez@email.com 2023-07-03      46
# 6    7   Mike Brown   30   mike.brown@email.com 2022-04-20   48000
# 7    8   Mary Jones   34   mary.jones@email.com 2021-03-15   52000
# 8    9          NaN   25      unknown@email.com 2020-08-10   42000
# 9   10    Lucas Roy   27    lucas.roy@email.com 2023-01-05      46
# 10  11  Elena Gomez   31  elena.gomez@email.com 2023-07-03   49500
# 11  12     David Li   30      davidli@email.com 2022-12-10   49000
# 12  13     David Li   30      davidli@email.com 2022-12-10   49000
# ...

# %%
dr.loc[2,"Salary"] = 48000

# %%
dr
# Out:
#     ID         Name  Age                  Email  Join Date  Salary  \
# 0    1   John Smith   29   john.smith@email.com 2020-01-15   45000
# 1    2   Mary Jones   34    mary.jones@emailcom 2021-03-15   52000
# 2    3   Mike Brown   30   mike.brown@email.com 2022-04-20   48000
# 3    4   Anna White   28   anna.white@email.com 2021-11-03   50000
# 4    5   John Smith   29   john.smith@email.com 2020-01-15   45000
# 5    6  Elena Gomez   31  elena.gomez@email.com 2023-07-03      46
# 6    7   Mike Brown   30   mike.brown@email.com 2022-04-20   48000
# 7    8   Mary Jones   34   mary.jones@email.com 2021-03-15   52000
# 8    9          NaN   25      unknown@email.com 2020-08-10   42000
# 9   10    Lucas Roy   27    lucas.roy@email.com 2023-01-05      46
# 10  11  Elena Gomez   31  elena.gomez@email.com 2023-07-03   49500
# 11  12     David Li   30      davidli@email.com 2022-12-10   49000
# 12  13     David Li   30      davidli@email.com 2022-12-10   49000
# ...

# %%
dr.loc[5,"Salary"] = 46000

# %%
dr
# Out:
#     ID         Name  Age                  Email  Join Date  Salary  \
# 0    1   John Smith   29   john.smith@email.com 2020-01-15   45000
# 1    2   Mary Jones   34    mary.jones@emailcom 2021-03-15   52000
# 2    3   Mike Brown   30   mike.brown@email.com 2022-04-20   48000
# 3    4   Anna White   28   anna.white@email.com 2021-11-03   50000
# 4    5   John Smith   29   john.smith@email.com 2020-01-15   45000
# 5    6  Elena Gomez   31  elena.gomez@email.com 2023-07-03   46000
# 6    7   Mike Brown   30   mike.brown@email.com 2022-04-20   48000
# 7    8   Mary Jones   34   mary.jones@email.com 2021-03-15   52000
# 8    9          NaN   25      unknown@email.com 2020-08-10   42000
# 9   10    Lucas Roy   27    lucas.roy@email.com 2023-01-05      46
# 10  11  Elena Gomez   31  elena.gomez@email.com 2023-07-03   49500
# 11  12     David Li   30      davidli@email.com 2022-12-10   49000
# 12  13     David Li   30      davidli@email.com 2022-12-10   49000
# ...

# %%
dr.drop(index=12,inplace=True)

# %%
dr
# Out:
#     ID         Name  Age                  Email  Join Date  Salary  \
# 0    1   John Smith   29   john.smith@email.com 2020-01-15   45000
# 1    2   Mary Jones   34    mary.jones@emailcom 2021-03-15   52000
# 2    3   Mike Brown   30   mike.brown@email.com 2022-04-20   48000
# 3    4   Anna White   28   anna.white@email.com 2021-11-03   50000
# 4    5   John Smith   29   john.smith@email.com 2020-01-15   45000
# 5    6  Elena Gomez   31  elena.gomez@email.com 2023-07-03   46000
# 6    7   Mike Brown   30   mike.brown@email.com 2022-04-20   48000
# 7    8   Mary Jones   34   mary.jones@email.com 2021-03-15   52000
# 8    9          NaN   25      unknown@email.com 2020-08-10   42000
# 9   10    Lucas Roy   27    lucas.roy@email.com 2023-01-05      46
# 10  11  Elena Gomez   31  elena.gomez@email.com 2023-07-03   49500
# 11  12     David Li   30      davidli@email.com 2022-12-10   49000
# 13  14  Maria Smith   30   maria.smith@emailcom 2019-06-01   53000
# ...

# %%
dr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          19 non-null     int64
#  1   Name        17 non-null     object
#  2   Age         19 non-null     int32
#  3   Email       19 non-null     object
#  4   Join Date   19 non-null     datetime64[ns]
#  5   Salary      19 non-null     int32
#  6   Department  19 non-null     object
# dtypes: datetime64[ns](1), int32(2), int64(1), object(3)
# memory usage: 1.0+ KB

# %%
dr.isnull().sum()
# Out:
# ID            0
# Name          2
# Age           0
# Email         0
# Join Date     0
# Salary        0
# Department    0
# dtype: int64

# %%
dr["Name"] = dr["Name"].dropna()

# %%
dr
# Out:
#     ID         Name  Age                  Email  Join Date  Salary  \
# 0    1   John Smith   29   john.smith@email.com 2020-01-15   45000
# 1    2   Mary Jones   34    mary.jones@emailcom 2021-03-15   52000
# 2    3   Mike Brown   30   mike.brown@email.com 2022-04-20   48000
# 3    4   Anna White   28   anna.white@email.com 2021-11-03   50000
# 4    5   John Smith   29   john.smith@email.com 2020-01-15   45000
# 5    6  Elena Gomez   31  elena.gomez@email.com 2023-07-03   46000
# 6    7   Mike Brown   30   mike.brown@email.com 2022-04-20   48000
# 7    8   Mary Jones   34   mary.jones@email.com 2021-03-15   52000
# 8    9          NaN   25      unknown@email.com 2020-08-10   42000
# 9   10    Lucas Roy   27    lucas.roy@email.com 2023-01-05      46
# 10  11  Elena Gomez   31  elena.gomez@email.com 2023-07-03   49500
# 11  12     David Li   30      davidli@email.com 2022-12-10   49000
# 13  14  Maria Smith   30   maria.smith@emailcom 2019-06-01   53000
# ...

# %%
dr.loc[10,"Salary"] = 46000

# %%
dr
# Out:
#     ID         Name  Age                  Email  Join Date  Salary  \
# 0    1   John Smith   29   john.smith@email.com 2020-01-15   45000
# 1    2   Mary Jones   34    mary.jones@emailcom 2021-03-15   52000
# 2    3   Mike Brown   30   mike.brown@email.com 2022-04-20   48000
# 3    4   Anna White   28   anna.white@email.com 2021-11-03   50000
# 4    5   John Smith   29   john.smith@email.com 2020-01-15   45000
# 5    6  Elena Gomez   31  elena.gomez@email.com 2023-07-03   46000
# 6    7   Mike Brown   30   mike.brown@email.com 2022-04-20   48000
# 7    8   Mary Jones   34   mary.jones@email.com 2021-03-15   52000
# 8    9          NaN   25      unknown@email.com 2020-08-10   42000
# 9   10    Lucas Roy   27    lucas.roy@email.com 2023-01-05      46
# 10  11  Elena Gomez   31  elena.gomez@email.com 2023-07-03   46000
# 11  12     David Li   30      davidli@email.com 2022-12-10   49000
# 13  14  Maria Smith   30   maria.smith@emailcom 2019-06-01   53000
# ...

# %%
dr.loc[19] = [20,"kitu",21,"abc@gmail.com","2020-02-15",48000,"IT"]

# %%
dr
# Out:
#     ID         Name  Age                  Email  Join Date  Salary  \
# 0    1   John Smith   29   john.smith@email.com 2020-01-15   45000
# 1    2   Mary Jones   34    mary.jones@emailcom 2021-03-15   52000
# 2    3   Mike Brown   30   mike.brown@email.com 2022-04-20   48000
# 3    4   Anna White   28   anna.white@email.com 2021-11-03   50000
# 4    5   John Smith   29   john.smith@email.com 2020-01-15   45000
# 5    6  Elena Gomez   31  elena.gomez@email.com 2023-07-03   46000
# 6    7   Mike Brown   30   mike.brown@email.com 2022-04-20   48000
# 7    8   Mary Jones   34   mary.jones@email.com 2021-03-15   52000
# 8    9          NaN   25      unknown@email.com 2020-08-10   42000
# 9   10    Lucas Roy   27    lucas.roy@email.com 2023-01-05      46
# 10  11  Elena Gomez   31  elena.gomez@email.com 2023-07-03   46000
# 11  12     David Li   30      davidli@email.com 2022-12-10   49000
# 13  14  Maria Smith   30   maria.smith@emailcom 2019-06-01   53000
# ...
