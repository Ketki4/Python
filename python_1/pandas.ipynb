# %%
import numpy as np

import pandas as pd

# %%
data1 = {"name":["om","kitu","pihu","tom"],
         "roll no":[1,2,3,4],
         "city":["pune","ngp","mumbai","satara"]
}

# %%
print(data1)
# Out:
# {'name': ['om', 'kitu', 'pihu', 'tom'], 'roll no': [1, 2, 3, 4], 'city': ['pune', 'ngp', 'mumbai', 'satara']}

# %%
data1 = pd.DataFrame(data1)

# %%
print(data1)
# Out:
#    name  roll no    city
# 0    om        1    pune
# 1  kitu        2     ngp
# 2  pihu        3  mumbai
# 3   tom        4  satara

# %%
data2 ={"roll no":[1,2,3,4],
        "age":[21,22,23,24]

}

# %%
print(data2)
# Out:
# {'roll no': [1, 2, 3, 4], 'age': [21, 22, 23, 24]}

# %%
data2=pd.DataFrame(data2)

# %%
print(data2)
# Out:
#    roll no  age
# 0        1   21
# 1        2   22
# 2        3   23
# 3        4   24

# %%
data_all=pd.merge(data1,data2)

# %%
print(data_all)
# Out:
#    name  roll no    city  age
# 0    om        1    pune   21
# 1  kitu        2     ngp   22
# 2  pihu        3  mumbai   23
# 3   tom        4  satara   24
